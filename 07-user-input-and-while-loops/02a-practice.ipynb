# %% [markdown]
# # User Input and While Loops
#
# ## Practice
#
# When buying tickets to a movie, your age determines which movies you're allowed to see (G, PG, PG-13, R). Write a `while` loop that asks a user for their age, then prints the highest rated movie they are allowed to see. Include a quit prompt that will use `break` to stop the loop. Can you think of a reasonable use for the `continue` statement in this example?

# %%
while True:
    age_str = input("enter your age (q to quit): ")
    if age_str == "q":
        break
    else:
        age = float(age_str)
    
    if age >= 18:
        print("you can see pirate movies (arrrrrr rated)")
    elif 13 <= age < 18:
        print("you can see PG13 movies, but you're not cool enough for R")
    elif 4 < age < 13:
        print("stick to ipad kid brainrot")
    elif 4 >= age:
        print("you're a little baby and probably cry on airplanes")
# Out:
# you're a little baby and probably cry on airplanes
# stick to ipad kid brainrot
